# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
channels = ['ch_'+str(i) for i in range(1,15)]

# %%
data= pd.read_csv('25-users/Abhishek_1.txt', sep=" ", header=None, names=channels)

# %%
data
# Out:
#             ch_1         ch_2         ch_3         ch_4         ch_5  \
# 0    4181.538462  4159.487179  4178.461538  4200.000000  4226.666667
# 1    4176.410256  4152.307692  4179.487179  4194.871795  4221.538462
# 2    4183.076923  4155.384615  4186.153846  4200.000000  4223.076923
# 3    4184.102564  4162.564103  4186.666667  4202.051282  4223.589744
# 4    4180.000000  4154.358974  4182.051282  4194.871795  4222.051282
# ..           ...          ...          ...          ...          ...
# 507  4221.538462  4178.974359  4195.897436  4200.000000  4226.153846
# 508  4229.230769  4191.282051  4202.564103  4206.153846  4224.102564
# 509  4233.333333  4206.153846  4211.282051  4213.846154  4221.538462
# 510  4232.307692  4205.641026  4214.871795  4214.871795  4223.076923
# 511  4236.410256  4207.179487  4222.051282  4213.846154  4223.076923
#
#             ch_6         ch_7         ch_8         ch_9        ch_10  \
# ...

# %%
plt.plot(data)

# %%
t = [i/128 for i in range(0, 512)] #plotting with time frame

# %%
print(plt.plot(t , data))
# Out:
# [<matplotlib.lines.Line2D object at 0x0000012A487C3BB0>, <matplotlib.lines.Line2D object at 0x0000012A487C3A60>, <matplotlib.lines.Line2D object at 0x0000012A487C3910>, <matplotlib.lines.Line2D object at 0x0000012A487C37C0>, <matplotlib.lines.Line2D object at 0x0000012A487C3670>, <matplotlib.lines.Line2D object at 0x0000012A487C3520>, <matplotlib.lines.Line2D object at 0x0000012A487C33D0>, <matplotlib.lines.Line2D object at 0x0000012A487C32B0>, <matplotlib.lines.Line2D object at 0x0000012A487C3130>, <matplotlib.lines.Line2D object at 0x0000012A46199490>, <matplotlib.lines.Line2D object at 0x0000012A418730D0>, <matplotlib.lines.Line2D object at 0x0000012A43BAF910>, <matplotlib.lines.Line2D object at 0x0000012A43BAFA30>, <matplotlib.lines.Line2D object at 0x0000012A43BAF640>]

# %%
data.describe()
# Out:
#               ch_1         ch_2         ch_3         ch_4         ch_5  \
# count   512.000000   512.000000   512.000000   512.000000   512.000000
# mean   4230.159255  4222.278646  4225.505809  4224.849760  4224.265825
# std      35.829823    57.797531    42.405780    33.966588     1.831677
# min    4154.871795  4100.000000  4150.256410  4157.435897  4217.948718
# 25%    4203.076923  4177.948718  4190.256410  4194.358974  4223.076923
# 50%    4232.051282  4216.923077  4220.512821  4229.487179  4224.102564
# 75%    4255.512820  4268.461538  4255.512820  4250.256410  4225.641026
# max    4302.051282  4340.512821  4316.410256  4283.076923  4229.230769
#
#               ch_6         ch_7         ch_8         ch_9        ch_10  \
# count   512.000000   512.000000   512.000000   512.000000   512.000000
# mean   4219.994992  4218.914263  4219.164663  4220.095152  4222.397837
# std      52.356455    56.519871    49.722130    63.196830     4.502222
# ...

# %%
data2 = data.div(1000000)

# %%
data2.describe()
# Out:
#              ch_1        ch_2        ch_3        ch_4        ch_5        ch_6  \
# count  512.000000  512.000000  512.000000  512.000000  512.000000  512.000000
# mean     0.004390    0.004498    0.004402    0.004385    0.004224    0.004445
# std      0.000240    0.000297    0.000211    0.000515    0.000019    0.000245
# min      0.003690    0.003701    0.003835    0.002679    0.004182    0.003781
# 25%      0.004318    0.004353    0.004317    0.004341    0.004210    0.004320
# 50%      0.004477    0.004543    0.004426    0.004610    0.004234    0.004508
# 75%      0.004554    0.004725    0.004564    0.004705    0.004238    0.004631
# max      0.004671    0.005040    0.004736    0.004760    0.004247    0.004832
#
#              ch_7        ch_8        ch_9       ch_10       ch_11       ch_12  \
# count  512.000000  512.000000  512.000000  512.000000  512.000000  512.000000
# mean     0.004466    0.004442    0.004502    0.004221    0.004489    0.004384
# ...

# %%
plt.plot(t , data2)

# %%
data_1= pd.read_csv('25-users/Abhishek_1.txt', sep=" ", header=None, names=channels)
data_2 = pd.read_csv('25-users/Abhishek_2.txt', sep=" ", header=None, names=channels)
data_3 = data = pd.read_csv('25-users/Abhishek_10.txt', sep=" ", header=None, names=channels)
data_4 = pd.read_csv('25-users/Abhishek_11.txt', sep=" ", header=None, names=channels)

# %%
plt.figure(figsize=(20,10))

plt.subplot(2,2,1)
plt.plot( t , data_1 ) #Abhishek_1.txt
plt.title('like_1')
plt.subplot(2,2,2)
plt.plot( t , data_2 ) #Abhishek_2.txt
plt.title('like_2')
plt.subplot(2,2,3)
plt.plot( t ,  data_3 ) #Abhishek_10.txt
plt.title('dislike_1')
plt.subplot(2,2,4)
plt.plot( t , data_4 ) #Abhishek_11.txt
plt.title('dislike_2')
# Out:
# Text(0.5, 1.0, 'dislike_2')

# %%
#all channels data of 'data' ie first data file (Abhishek_1.txt)
plt.figure(figsize=(30,30))
for i , col in enumerate(channels,1):
    plt.subplot(4,4,i)
    plt.plot(t , data_1[col])
